# %% [markdown]
# # Data Exploration

# %%
import pandas as pd
import harry_plotter

from constants import *
from os.path import join

# %% [markdown]
# Load orbit $n$

# %%
n = 42

# %%
orbit = pd.read_csv(join(ORBIT_DIR, ORBIT_FILE(n)),
                    index_col=DATE_COL,
                    parse_dates=True)

# %% [markdown]
# Peek into the data

# %%
orbit.head()
# Out:
#                            X_MSO        Y_MSO         Z_MSO  BX_MSO  BY_MSO  \
# DATE
# 2011-04-13 10:34:22  5994.666016 -5966.287109 -15414.500977  -5.228   3.356
# 2011-04-13 10:34:23  5995.121094 -5966.539062 -15414.238281  -5.186   3.293
# 2011-04-13 10:34:24  5995.576172 -5966.791016 -15413.974609  -4.887   3.500
# 2011-04-13 10:34:25  5996.030762 -5967.042969 -15413.711914  -4.214   4.172
# 2011-04-13 10:34:26  5996.485840 -5967.294922 -15413.449219  -4.608   3.046
#
#                      BZ_MSO  DBX_MSO  DBY_MSO  DBZ_MSO    RHO_DIPOLE  ...  \
# DATE                                                                  ...
# 2011-04-13 10:34:22   0.500    0.275    0.212    0.158  18008.191406  ...
# 2011-04-13 10:34:23   0.360    0.099    0.186    0.289  18008.193359  ...
# 2011-04-13 10:34:24   1.260    0.164    0.392    0.210  18008.197266  ...
# 2011-04-13 10:34:25   0.611    0.210    0.199    0.377  18008.199219  ...
# 2011-04-13 10:34:26   0.545    0.480    0.667    0.511  18008.201172  ...
#
#                               X           Y          Z         VX         VY  \
# DATE
# 2011-04-13 10:34:22 -55126012.0 -33756444.0  2300070.5  15.427609 -39.399944
# 2011-04-13 10:34:23 -55126012.0 -33756444.0  2300070.5  15.427609 -39.399944
# 2011-04-13 10:34:24 -55126012.0 -33756444.0  2300070.5  15.427609 -39.399944
# 2011-04-13 10:34:25 -55126012.0 -33756444.0  2300070.5  15.427609 -39.399944
# 2011-04-13 10:34:26 -55126012.0 -33756444.0  2300070.5  15.427609 -39.399944
#
#                            VZ       VABS           D  COSALPHA  EXTREMA
# DATE
# 2011-04-13 10:34:22 -4.634681  42.565796  64681260.0 -0.815553        2
# 2011-04-13 10:34:23 -4.634664  42.565792  64681260.0 -0.815553        0
# 2011-04-13 10:34:24 -4.634715  42.565800  64681260.0 -0.815553        0
# 2011-04-13 10:34:25 -4.634736  42.565800  64681260.0 -0.815553        0
# 2011-04-13 10:34:26 -4.634744  42.565804  64681260.0 -0.815553        0
#
# [5 rows x 28 columns]

# %%
orbit.info(False)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 43462 entries, 2011-04-13 10:34:22 to 2011-04-13 22:38:43
# Columns: 28 entries, X_MSO to EXTREMA
# dtypes: float32(27), int8(1)
# memory usage: 4.8 MB

# %%
sorted(orbit.EXTREMA.unique())
# Out:
# [-2, -1, 0, 1, 2]

# %% [markdown]
# Plot magnetic flux density

# %%
harry_plotter.plot_components_and_norm(
    orbit.index,
    (orbit.BX_MSO,
    orbit.BY_MSO,
    orbit.BZ_MSO),
    symbol="B",
    outfile=join(FIGURE_DIR, MESSENGER(n) + "_flux.pdf")
)

# %% [markdown]
# Plot position of spacecraft

# %%
harry_plotter.plot_components_and_norm(
    orbit.index,
    (orbit.X_MSO,
    orbit.Y_MSO,
    orbit.Z_MSO),
    symbol="x",
    outfile=join(FIGURE_DIR, MESSENGER(n) + "_position.pdf")
)
