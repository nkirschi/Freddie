# %% [markdown]
# # Dataset Test

# %%
import utils

from messenger_dataset import ClassificationDataset, PredictionDataset
from constants import *

# %% [markdown]
# ## `ClassificationDataset`

# %% [markdown]
# Load training data

# %%
ds = ClassificationDataset(utils.resolve_path(DATA_DIR, TRAIN_FILE), window_size=10, normalize=False, partial=True)
print(len(ds))
# Out:
# 999487

# %% [markdown]
# Inspect sample-label pair at label change

# %%
sample, label = ds[16604]
print(sample)
print(label)
# Out:
# tensor([[[-4.0224e+01,  2.5149e+01,  1.5014e+01],
#          [ 5.8049e+03,  7.0819e+03, -2.4301e+03]],
#
#         [[-4.4922e+01,  1.6665e+01,  4.7840e+00],
#          [ 5.8043e+03,  7.0813e+03, -2.4287e+03]],
#
#         [[-3.7371e+01,  8.1360e+00,  7.6070e+00],
#          [ 5.8036e+03,  7.0807e+03, -2.4274e+03]],
#
#         [[-3.4104e+01,  4.6560e+00,  1.4430e+01],
#          [ 5.8030e+03,  7.0801e+03, -2.4261e+03]],
#
#         [[-3.7385e+01, -4.4900e-01,  2.3100e+01],
#          [ 5.8024e+03,  7.0795e+03, -2.4248e+03]],
#
#         [[-3.1174e+01,  2.7860e+00,  3.5948e+01],
#          [ 5.8017e+03,  7.0790e+03, -2.4235e+03]],
#
#         [[-3.1384e+01,  2.1804e+01,  3.5631e+01],
#          [ 5.8011e+03,  7.0784e+03, -2.4221e+03]],
#
#         [[-3.8439e+01,  3.0902e+01,  2.2061e+01],
#          [ 5.8004e+03,  7.0778e+03, -2.4208e+03]],
#
#         [[-4.3713e+01,  2.8769e+01,  1.1771e+01],
#          [ 5.7998e+03,  7.0772e+03, -2.4195e+03]],
#
# ...

# %% [markdown]
# Inspect sample-label pair at orbit change

# %%
sample, label = ds[43455]
print(sample)
print(label)
# Out:
# tensor([[[ 2.9540e+01, -1.7130e+00, -8.6330e+00],
#          [ 6.8982e+03,  5.4039e+03, -1.5374e+04]],
#
#         [[ 2.9849e+01, -9.7700e-01, -1.0833e+01],
#          [ 6.8985e+03,  5.4043e+03, -1.5374e+04]],
#
#         [[ 2.9333e+01, -2.7520e+00, -1.2014e+01],
#          [ 6.8988e+03,  5.4047e+03, -1.5374e+04]],
#
#         [[ 3.0229e+01, -4.7280e+00, -9.0650e+00],
#          [ 6.8991e+03,  5.4051e+03, -1.5373e+04]],
#
#         [[ 2.9527e+01, -1.3570e+00, -9.5890e+00],
#          [ 6.8994e+03,  5.4055e+03, -1.5373e+04]],
#
#         [[ 2.9926e+01, -4.1730e+00, -1.1534e+01],
#          [ 6.8997e+03,  5.4059e+03, -1.5373e+04]],
#
#         [[ 2.8045e+01, -4.7510e+00, -1.3275e+01],
#          [ 6.9000e+03,  5.4063e+03, -1.5372e+04]],
#
#         [[ 3.1665e+01, -2.3210e+00, -9.3490e+00],
#          [ 6.9003e+03,  5.4067e+03, -1.5372e+04]],
#
#         [[ 2.8085e+01, -2.5650e+00, -1.1889e+01],
#          [ 6.9006e+03,  5.4071e+03, -1.5372e+04]],
#
# ...

# %% [markdown]
# View first and last element

# %%
print(ds[0])
# Out:
# (tensor([[[-3.5407e+01,  1.5722e+01,  4.9990e+00],
#          [ 6.6301e+03,  5.7393e+03, -1.5373e+04]],
#
#         [[-3.5976e+01,  1.4327e+01,  3.4010e+00],
#          [ 6.6304e+03,  5.7397e+03, -1.5373e+04]],
#
#         [[-3.4115e+01,  1.7308e+01,  3.0780e+00],
#          [ 6.6306e+03,  5.7401e+03, -1.5373e+04]],
#
#         [[-3.4830e+01,  1.7010e+01,  4.8460e+00],
#          [ 6.6309e+03,  5.7406e+03, -1.5372e+04]],
#
#         [[-3.7102e+01,  1.4965e+01,  6.4000e-01],
#          [ 6.6312e+03,  5.7410e+03, -1.5372e+04]],
#
#         [[-3.5001e+01,  1.8250e+01, -1.3470e+00],
#          [ 6.6315e+03,  5.7414e+03, -1.5372e+04]],
#
#         [[-3.6001e+01,  1.7970e+01,  9.0000e-01],
#          [ 6.6317e+03,  5.7418e+03, -1.5371e+04]],
#
#         [[-3.7091e+01,  1.7390e+01,  8.3000e-01],
#          [ 6.6320e+03,  5.7422e+03, -1.5371e+04]],
#
#         [[-3.6750e+01,  1.8102e+01, -1.0810e+00],
#          [ 6.6323e+03,  5.7426e+03, -1.5371e+04]],
#
# ...

# %%
print(ds[len(ds) - 1])
# Out:
# (tensor([[[ 1.7441e+01, -4.4660e+00,  4.4460e+00],
#          [ 7.9000e+03, -3.1959e+03, -1.5410e+04]],
#
#         [[ 1.7282e+01, -4.4940e+00,  4.8450e+00],
#          [ 7.9005e+03, -3.1960e+03, -1.5409e+04]],
#
#         [[ 1.7266e+01, -4.4660e+00,  4.5360e+00],
#          [ 7.9011e+03, -3.1960e+03, -1.5409e+04]],
#
#         [[ 1.7264e+01, -4.5110e+00,  4.7290e+00],
#          [ 7.9016e+03, -3.1961e+03, -1.5409e+04]],
#
#         [[ 1.7308e+01, -4.3070e+00,  4.2750e+00],
#          [ 7.9021e+03, -3.1962e+03, -1.5409e+04]],
#
#         [[ 1.7301e+01, -4.4900e+00,  4.4170e+00],
#          [ 7.9026e+03, -3.1962e+03, -1.5408e+04]],
#
#         [[ 1.7395e+01, -4.3740e+00,  4.3110e+00],
#          [ 7.9031e+03, -3.1963e+03, -1.5408e+04]],
#
#         [[ 1.7377e+01, -4.5070e+00,  4.1780e+00],
#          [ 7.9036e+03, -3.1963e+03, -1.5408e+04]],
#
#         [[ 1.7365e+01, -4.4750e+00,  4.4720e+00],
#          [ 7.9041e+03, -3.1964e+03, -1.5408e+04]],
#
# ...

# %% [markdown]
# ## `PredictionDataset`

# %% [markdown]
# Load training data

# %%
ds = PredictionDataset(utils.resolve_path(DATA_DIR, TRAIN_FILE), window_size=10, normalize=False, partial=True)
print(len(ds))
# Out:
# 999464

# %% [markdown]
# Inspect sample-label pair at label change

# %%
sample, label = ds[16597]
print(sample)
print(label)
# Out:
# tensor([[[-4.3372e+01,  1.9557e+01, -4.9470e+00],
#          [ 5.8094e+03,  7.0859e+03, -2.4393e+03]],
#
#         [[-3.9380e+01,  1.5616e+01,  5.1620e+00],
#          [ 5.8087e+03,  7.0853e+03, -2.4380e+03]],
#
#         [[-3.5410e+01,  2.5193e+01,  4.8810e+00],
#          [ 5.8081e+03,  7.0847e+03, -2.4367e+03]],
#
#         [[-4.1957e+01,  2.3986e+01, -2.2310e+00],
#          [ 5.8075e+03,  7.0842e+03, -2.4353e+03]],
#
#         [[-3.8664e+01,  1.3664e+01, -3.6260e+00],
#          [ 5.8068e+03,  7.0836e+03, -2.4340e+03]],
#
#         [[-3.7162e+01,  1.1146e+01,  1.4918e+01],
#          [ 5.8062e+03,  7.0830e+03, -2.4327e+03]],
#
#         [[-3.7199e+01,  2.4898e+01,  1.8829e+01],
#          [ 5.8055e+03,  7.0824e+03, -2.4314e+03]],
#
#         [[-4.0224e+01,  2.5149e+01,  1.5014e+01],
#          [ 5.8049e+03,  7.0819e+03, -2.4301e+03]],
#
#         [[-4.4922e+01,  1.6665e+01,  4.7840e+00],
#          [ 5.8043e+03,  7.0813e+03, -2.4287e+03]],
#
# ...

# %% [markdown]
# Inspect sample-label pair at orbit change

# %%
sample, label = ds[43454]
print(sample)
print(label)
# Out:
# tensor([[[ 2.9540e+01, -1.7130e+00, -8.6330e+00],
#          [ 6.8982e+03,  5.4039e+03, -1.5374e+04]],
#
#         [[ 2.9849e+01, -9.7700e-01, -1.0833e+01],
#          [ 6.8985e+03,  5.4043e+03, -1.5374e+04]],
#
#         [[ 2.9333e+01, -2.7520e+00, -1.2014e+01],
#          [ 6.8988e+03,  5.4047e+03, -1.5374e+04]],
#
#         [[ 3.0229e+01, -4.7280e+00, -9.0650e+00],
#          [ 6.8991e+03,  5.4051e+03, -1.5373e+04]],
#
#         [[ 2.9527e+01, -1.3570e+00, -9.5890e+00],
#          [ 6.8994e+03,  5.4055e+03, -1.5373e+04]],
#
#         [[ 2.9926e+01, -4.1730e+00, -1.1534e+01],
#          [ 6.8997e+03,  5.4059e+03, -1.5373e+04]],
#
#         [[ 2.8045e+01, -4.7510e+00, -1.3275e+01],
#          [ 6.9000e+03,  5.4063e+03, -1.5372e+04]],
#
#         [[ 3.1665e+01, -2.3210e+00, -9.3490e+00],
#          [ 6.9003e+03,  5.4067e+03, -1.5372e+04]],
#
#         [[ 2.8085e+01, -2.5650e+00, -1.1889e+01],
#          [ 6.9006e+03,  5.4071e+03, -1.5372e+04]],
#
# ...

# %% [markdown]
# View first and last element

# %%
print(ds[0])
# Out:
# (tensor([[[-3.5407e+01,  1.5722e+01,  4.9990e+00],
#          [ 6.6301e+03,  5.7393e+03, -1.5373e+04]],
#
#         [[-3.5976e+01,  1.4327e+01,  3.4010e+00],
#          [ 6.6304e+03,  5.7397e+03, -1.5373e+04]],
#
#         [[-3.4115e+01,  1.7308e+01,  3.0780e+00],
#          [ 6.6306e+03,  5.7401e+03, -1.5373e+04]],
#
#         [[-3.4830e+01,  1.7010e+01,  4.8460e+00],
#          [ 6.6309e+03,  5.7406e+03, -1.5372e+04]],
#
#         [[-3.7102e+01,  1.4965e+01,  6.4000e-01],
#          [ 6.6312e+03,  5.7410e+03, -1.5372e+04]],
#
#         [[-3.5001e+01,  1.8250e+01, -1.3470e+00],
#          [ 6.6315e+03,  5.7414e+03, -1.5372e+04]],
#
#         [[-3.6001e+01,  1.7970e+01,  9.0000e-01],
#          [ 6.6317e+03,  5.7418e+03, -1.5371e+04]],
#
#         [[-3.7091e+01,  1.7390e+01,  8.3000e-01],
#          [ 6.6320e+03,  5.7422e+03, -1.5371e+04]],
#
#         [[-3.6750e+01,  1.8102e+01, -1.0810e+00],
#          [ 6.6323e+03,  5.7426e+03, -1.5371e+04]],
#
# ...

# %%
print(ds[len(ds) - 1])
# Out:
# (tensor([[[ 1.7653e+01, -4.3380e+00,  4.4680e+00],
#          [ 7.8995e+03, -3.1959e+03, -1.5410e+04]],
#
#         [[ 1.7441e+01, -4.4660e+00,  4.4460e+00],
#          [ 7.9000e+03, -3.1959e+03, -1.5410e+04]],
#
#         [[ 1.7282e+01, -4.4940e+00,  4.8450e+00],
#          [ 7.9005e+03, -3.1960e+03, -1.5409e+04]],
#
#         [[ 1.7266e+01, -4.4660e+00,  4.5360e+00],
#          [ 7.9011e+03, -3.1960e+03, -1.5409e+04]],
#
#         [[ 1.7264e+01, -4.5110e+00,  4.7290e+00],
#          [ 7.9016e+03, -3.1961e+03, -1.5409e+04]],
#
#         [[ 1.7308e+01, -4.3070e+00,  4.2750e+00],
#          [ 7.9021e+03, -3.1962e+03, -1.5409e+04]],
#
#         [[ 1.7301e+01, -4.4900e+00,  4.4170e+00],
#          [ 7.9026e+03, -3.1962e+03, -1.5408e+04]],
#
#         [[ 1.7395e+01, -4.3740e+00,  4.3110e+00],
#          [ 7.9031e+03, -3.1963e+03, -1.5408e+04]],
#
#         [[ 1.7377e+01, -4.5070e+00,  4.1780e+00],
#          [ 7.9036e+03, -3.1963e+03, -1.5408e+04]],
#
# ...
