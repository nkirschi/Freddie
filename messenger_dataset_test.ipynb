# %% [markdown]
# # `MessengerDataset` Test

# %%
from messenger_dataset import MessengerDataset

from constants import *
from os.path import join

# %% [markdown]
# Class name mapping

# %%
label_names = {
    0: "IMF",
    1: "BS crossing",
    2: "magnetosheath",
    3: "MP crossing",
    4: "magnetosphere"
}

# %% [markdown]
# Load training data

# %%
ds = MessengerDataset(join(MERGED_DIR, TRAIN_FILE), normalize=False)
print(len(ds))
# Out:
# 91079730

# %% [markdown]
# Inspect sample-label pair

# %%
sample, label = ds[16604]
print(sample)
print(label)
# Out:
# tensor([[[-2.9283e+07,  3.8781e+07,  5.8555e+06],
#          [-4.8713e+01, -2.7442e+01,  2.2276e+00],
#          [ 5.8049e+03,  7.0819e+03, -2.4301e+03],
#          [-4.0224e+01,  2.5149e+01,  1.5014e+01],
#          [ 4.2700e+00,  1.1650e+00,  5.4290e+00],
#          [ 1.7634e+00,  2.1513e+00,  2.3235e+00]],
#
#         [[-2.9283e+07,  3.8781e+07,  5.8555e+06],
#          [-4.8713e+01, -2.7442e+01,  2.2277e+00],
#          [ 5.8043e+03,  7.0813e+03, -2.4287e+03],
#          [-4.4922e+01,  1.6665e+01,  4.7840e+00],
#          [ 4.2390e+00,  6.3750e+00,  3.3690e+00],
#          [ 1.7635e+00,  2.1515e+00,  2.3249e+00]],
#
#         [[-2.9283e+07,  3.8781e+07,  5.8555e+06],
#          [-4.8713e+01, -2.7442e+01,  2.2277e+00],
#          [ 5.8036e+03,  7.0807e+03, -2.4274e+03],
#          [-3.7371e+01,  8.1360e+00,  7.6070e+00],
#          [ 2.3160e+00,  3.6720e+00,  3.4430e+00],
#          [ 1.7636e+00,  2.1517e+00,  2.3264e+00]],
#
#         [[-2.9283e+07,  3.8781e+07,  5.8555e+06],
# ...

# %% [markdown]
# View first and last element

# %%
print(ds[0])
print(ds[-1])
# Out:
# (tensor([[[-2.8472e+07,  3.9229e+07,  5.8177e+06],
#          [-4.9257e+01, -2.6708e+01,  2.3374e+00],
#          [ 6.6301e+03,  5.7393e+03, -1.5373e+04],
#          [-3.5407e+01,  1.5722e+01,  4.9990e+00],
#          [ 8.5000e-01,  9.4000e-01,  3.8600e-01],
#          [ 4.5969e-01,  3.9792e-01, -6.2087e-01]],
#
#         [[-2.8472e+07,  3.9229e+07,  5.8177e+06],
#          [-4.9257e+01, -2.6708e+01,  2.3375e+00],
#          [ 6.6304e+03,  5.7397e+03, -1.5373e+04],
#          [-3.5976e+01,  1.4327e+01,  3.4010e+00],
#          [ 6.0600e-01,  8.1100e-01,  7.2900e-01],
#          [ 4.5970e-01,  3.9795e-01, -6.2084e-01]],
#
#         [[-2.8472e+07,  3.9229e+07,  5.8177e+06],
#          [-4.9257e+01, -2.6708e+01,  2.3375e+00],
#          [ 6.6306e+03,  5.7401e+03, -1.5373e+04],
#          [-3.4115e+01,  1.7308e+01,  3.0780e+00],
#          [ 4.3400e-01,  6.6600e-01,  3.6700e-01],
#          [ 4.5971e-01,  3.9797e-01, -6.2080e-01]],
#
#         [[-2.8472e+07,  3.9229e+07,  5.8177e+06],
# ...
